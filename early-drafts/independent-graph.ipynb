# %%
from math import sin, cos, pi
G = graphs.CompleteGraph(9)
G.add_clique(range(5,13))
G.add_clique(range(19,22))
G.add_clique(range(11,16))
G.add_clique(range(16,19))
G.add_clique(range(21,26))
G.add_edge(0,14)
G.add_edge(0,11)
G.add_edge(0,15)
G.add_edge(0,19)
G.add_edge(0,20)
G.add_edge(0,21)
G.add_edge(1,11)
G.add_edge(1,12)
G.add_edge(1,15)
G.add_edge(1,17)
G.add_edge(1,20)
G.add_edge(2,18)
G.add_edge(2,21)
G.add_edge(3,9)
G.add_edge(3,11)
G.add_edge(3,15)
G.add_edge(5,18)
G.add_edge(5,20)
G.add_edge(6,14)
G.add_edge(6,16)
G.add_edge(6,19)
G.add_edge(6,20)
G.add_edge(7,15)
G.add_edge(7,18)
G.add_edge(7,19)
G.add_edge(8,13)
G.add_edge(8,15)
G.add_edge(8,19)
G.add_edge(9,15)
G.add_edge(9,18)
G.add_edge(9,23)
G.add_edge(9,25)
G.add_edge(10,16)
G.add_edge(10,22)
G.add_edge(10,25)
G.add_edge(13,22)
G.add_edge(13,23)
G.add_edge(14,16)
G.add_edge(14,17)
G.add_edge(14,22)
G.add_edge(14,24)
G.add_edge(17,19)
G.add_edge(17,24)
J=G.complement()
pos_dict = {}
#positions = list(range(26))
#shuffle(positions)
positions = [12, 6, 4, 25, 24, 21, 13, 14, 18, 20, 22, 1, 23, 9, 10, 11, 3, 19, 16, 0, 8, 2, 5, 15, 17, 7]
print(positions)
for i in range(26):
    x = float(cos(pi/2 + ((2*pi)/26)*positions[i]))
    y = float(sin(pi/2 + ((2*pi)/26)*positions[i]))
    pos_dict[i] = [x,y]
    
pl = J.graphplot(pos=pos_dict,vertex_size=10,vertex_labels=False)
H=pl.plot(dpi=300)
H.show()
# Out:
# [12, 6, 4, 25, 24, 21, 13, 14, 18, 20, 22, 1, 23, 9, 10, 11, 3, 19, 16, 0, 8, 2, 5, 15, 17, 7]
# Graphics object consisting of 200 graphics primitives

# %%
G = graphs.CompleteGraph(9)
G.add_clique(range(5,13))
G.add_clique(range(8,16))
G.add_clique(range(12,20))
J=G.complement()
pos_dict = {}
#positions = list(range(26))
#shuffle(positions)
positions = [
    1, 2, 4, 7, 8,
    10, 12, 14, 18, 19,
    0, 3, 5, 6, 9,
    11, 13, 15, 16, 17]
labels = [
        "B","A","t","T","e",
        "R","i","E","s","c",
        "D","f","G","h","K",
        "l","M","n","P","u"]
J.relabel(labels)
print(positions)
for i in range(20):
    x = float(cos(pi/2 + ((2*pi)/20)*positions[i]))
    y = float(sin(pi/2 + ((2*pi)/20)*positions[i]))
    pos_dict[labels[i]] = [x,y]


print(J.vertices())
pl = J.graphplot(pos=pos_dict,vertex_size=170,vertex_labels=True,vertex_color='#ddd')
H=pl.plot(dpi=300)
H.show()
# Out:
# [12, 6, 4, 13, 14, 18, 1, 9, 10, 11, 3, 19, 16, 0, 8, 2, 5, 15, 17, 7]
# ['A', 'B', 'D', 'E', 'G', 'K', 'M', 'P', 'R', 'T', 'c', 'e', 'f', 'h', 'i', 'l', 'n', 's', 't', 'u']
# Graphics object consisting of 113 graphics primitives
